# %%
#Import Mod
import pandas as pd
from datetime import datetime
import numpy as np
import math

# %% [markdown]
# ## Spray Dataset

# %%
spray = pd.read_csv('./dataset/spray.csv')
spray.head()
# Out:
#          Date        Time   Latitude  Longitude
# 0  2011-08-29  6:56:58 PM  42.391623 -88.089163
# 1  2011-08-29  6:57:08 PM  42.391348 -88.089163
# 2  2011-08-29  6:57:18 PM  42.391022 -88.089157
# 3  2011-08-29  6:57:28 PM  42.390637 -88.089158
# 4  2011-08-29  6:57:38 PM  42.390410 -88.088858

# %%
spray.dtypes
# Out:
# Date          object
# Time          object
# Latitude     float64
# Longitude    float64
# dtype: object

# %%
spray.shape
# Out:
# (14835, 4)

# %% [markdown]
# 4 Features, 14835 rows (samples)

# %%
spray.isnull().sum()
# Out:
# Date           0
# Time         584
# Latitude       0
# Longitude      0
# dtype: int64

# %%
spray[spray.Time.isnull()]
# Out:
#             Date Time   Latitude  Longitude
# 1030  2011-09-07  NaN  41.987092 -87.794286
# 1031  2011-09-07  NaN  41.987620 -87.794382
# 1032  2011-09-07  NaN  41.988004 -87.794574
# 1033  2011-09-07  NaN  41.988292 -87.795486
# 1034  2011-09-07  NaN  41.988100 -87.796014
# ...          ...  ...        ...        ...
# 1609  2011-09-07  NaN  41.995876 -87.811615
# 1610  2011-09-07  NaN  41.995972 -87.810271
# 1611  2011-09-07  NaN  41.995684 -87.810319
# 1612  2011-09-07  NaN  41.994724 -87.810415
# 1613  2011-09-07  NaN  41.993092 -87.810415
#
# [584 rows x 4 columns]

# %% [markdown]
# Dropping Time as it only indicate 2 hours window to spray and show low level of significant.

# %%
spray.drop('Time', axis=1, inplace=True)

# %%
spray.shape
# Out:
# (14835, 3)

# %% [markdown]
# ### Date datetime conversion

# %%
spray['Date'] = pd.to_datetime(spray['Date'])

# %%
spray.head()
# Out:
#         Date   Latitude  Longitude
# 0 2011-08-29  42.391623 -88.089163
# 1 2011-08-29  42.391348 -88.089163
# 2 2011-08-29  42.391022 -88.089157
# 3 2011-08-29  42.390637 -88.089158
# 4 2011-08-29  42.390410 -88.088858

# %%
spray.dtypes
# Out:
# Date         datetime64[ns]
# Latitude            float64
# Longitude           float64
# dtype: object

# %%
spray.Date.dt.day.head(2)
# Out:
# 0    29
# 1    29
# Name: Date, dtype: int64

# %%
spray.Date.dt.month.head(2)
# Out:
# 0    8
# 1    8
# Name: Date, dtype: int64

# %%
print(spray.Date.max())
spray.Date.min()
# Out:
# 2013-09-05 00:00:00
# Timestamp('2011-08-29 00:00:00')

# %%
spray.duplicated().sum()
# Out:
# 541

# %%
spray.drop_duplicates(inplace=True)

# %% [markdown]
# ### Export

# %%
spray.to_csv('./clean_data/spray_clean.csv', index = False)

# %% [markdown]
# ---

# %% [markdown]
# ## Weather Dataset

# %%
weather = pd.read_csv('./dataset/weather.csv')

# %%
weather.head()
# Out:
#    Station        Date  Tmax  Tmin Tavg Depart  DewPoint WetBulb Heat Cool  \
# 0        1  2007-05-01    83    50   67     14        51      56    0    2
# 1        2  2007-05-01    84    52   68      M        51      57    0    3
# 2        1  2007-05-02    59    42   51     -3        42      47   14    0
# 3        2  2007-05-02    60    43   52      M        42      47   13    0
# 4        1  2007-05-03    66    46   56      2        40      48    9    0
#
#    ... CodeSum Depth Water1 SnowFall PrecipTotal StnPressure SeaLevel  \
# 0  ...             0      M      0.0        0.00       29.10    29.82
# 1  ...             M      M        M        0.00       29.18    29.82
# 2  ...      BR     0      M      0.0        0.00       29.38    30.09
# 3  ...   BR HZ     M      M        M        0.00       29.44    30.08
# 4  ...             0      M      0.0        0.00       29.39    30.12
#
#   ResultSpeed ResultDir  AvgSpeed
# 0         1.7        27       9.2
# 1         2.7        25       9.6
# 2        13.0         4      13.4
# 3        13.3         2      13.4
# 4        11.7         7      11.9
#
# [5 rows x 22 columns]

# %%
weather.Station.value_counts() #Balanced sample size from station 1 and 2
# Out:
# 1    1472
# 2    1472
# Name: Station, dtype: int64

# %%
weather.shape
# Out:
# (2944, 22)

# %% [markdown]
# ### Cleaning Null

# %%
weather.isnull().sum()
# Out:
# Station        0
# Date           0
# Tmax           0
# Tmin           0
# Tavg           0
# Depart         0
# DewPoint       0
# WetBulb        0
# Heat           0
# Cool           0
# Sunrise        0
# Sunset         0
# CodeSum        0
# Depth          0
# Water1         0
# SnowFall       0
# PrecipTotal    0
# StnPressure    0
# SeaLevel       0
# ResultSpeed    0
# ResultDir      0
# AvgSpeed       0
# dtype: int64

# %%
weather.dtypes
# Out:
# Station          int64
# Date            object
# Tmax             int64
# Tmin             int64
# Tavg            object
# Depart          object
# DewPoint         int64
# WetBulb         object
# Heat            object
# Cool            object
# Sunrise         object
# Sunset          object
# CodeSum         object
# Depth           object
# Water1          object
# SnowFall        object
# PrecipTotal     object
# StnPressure     object
# SeaLevel        object
# ResultSpeed    float64
# ResultDir        int64
# AvgSpeed        object
# dtype: object

# %%
for col in weather.columns:
    if weather[col].dtype == 'object':
        print(weather[col].unique())
# Out:
# ['2007-05-01' '2007-05-02' '2007-05-03' ... '2014-10-29' '2014-10-30'
#  '2014-10-31']
# ['67' '68' '51' '52' '56' '58' 'M' '60' '59' '65' '70' '69' '71' '61' '55'
#  '57' '73' '72' '53' '62' '63' '74' '75' '78' '76' '77' '66' '80' '64'
#  '81' '82' '79' '85' '84' '83' '50' '49' '46' '48' '45' '54' '47' '44'
#  '40' '41' '38' '39' '42' '37' '43' '86' '87' '89' '92' '88' '91' '93'
#  '94' '90' '36']
# ['14' 'M' '-3' ' 2' ' 4' ' 5' '10' '12' '13' '-2' '15' '11' '-4' '-6' ' 8'
#  '-5' ' 1' ' 9' ' 6' '-9' '-8' ' 3' ' 0' '-1' '-7' ' 7' '-14' '18' '16'
#  '22' '21' '20' '-10' '-16' '17' '-12' '-11' '-15' '-17' '19' '-13' '23']
# ['56' '57' '47' '48' '50' '49' '46' '54' '53' '62' '63' '60' '61' '51'
#  '59' '58' '43' '44' '45' '65' '66' '67' '64' '52' '55' '69' '68' '70'
#  '72' '71' '73' '74' '76' '42' '39' '40' '41' '35' '33' '34' 'M' '75' '36'
#  '32' '38' '78' '77' '37']
# ['0' '14' '13' '9' '7' 'M' '5' '6' '4' '10' '8' '12' '3' '2' '1' '15' '16'
#  '19' '17' '20' '11' '18' '21' '25' '24' '27' '26' '23' '28' '22' '29']
# [' 2' ' 3' ' 0' 'M' ' 5' ' 4' ' 6' ' 8' ' 7' ' 9' '10' '13' '11' '12' ' 1'
#  '15' '16' '17' '14' '20' '19' '18' '21' '22' '24' '27' '23' '26' '28'
#  '29' '25']
# ['0448' '-' '0447' '0446' '0444' '0443' '0442' '0441' '0439' '0438' '0437'
#  '0436' '0435' '0434' '0433' '0432' '0431' '0430' '0429' '0428' '0427'
#  '0426' '0425' '0424' '0423' '0422' '0421' '0420' '0419' '0418' '0417'
#  '0416' '0440' '0445' '0449' '0450' '0451' '0452' '0453' '0454' '0455'
#  '0456' '0457' '0458' '0459' '0500' '0501' '0502' '0503' '0504' '0505'
#  '0506' '0508' '0509' '0510' '0511' '0512' '0513' '0514' '0515' '0516'
#  '0517' '0518' '0519' '0520' '0521' '0522' '0523' '0524' '0525' '0526'
#  '0527' '0528' '0529' '0530' '0531' '0532' '0533' '0535' '0536' '0537'
#  '0538' '0539' '0540' '0541' '0542' '0543' '0544' '0545' '0546' '0547'
#  '0548' '0549' '0550' '0552' '0553' '0554' '0555' '0556' '0557' '0558'
#  '0559' '0600' '0602' '0603' '0604' '0605' '0606' '0607' '0608' '0610'
#  '0611' '0612' '0613' '0614' '0616' '0617' '0618' '0619' '0620' '0622'
#  '0623']
# ['1849' '-' '1850' '1851' '1852' '1853' '1855' '1856' '1857' '1858' '1859'
#  '1860' '1901' '1902' '1903' '1904' '1905' '1906' '1907' '1908' '1909'
#  '1910' '1911' '1912' '1913' '1914' '1915' '1916' '1917' '1918' '1919'
#  '1920' '1921' '1922' '1923' '1924' '1925' '1926' '1927' '1928' '1929'
#  '1930' '1931' '1900' '1854' '1848' '1846' '1845' '1843' '1842' '1840'
#  '1839' '1837' '1835' '1834' '1832' '1831' '1829' '1827' '1826' '1824'
#  '1822' '1821' '1819' '1817' '1815' '1814' '1812' '1810' '1809' '1807'
#  '1805' '1803' '1760' '1758' '1756' '1755' '1753' '1751' '1749' '1748'
#  '1746' '1744' '1742' '1741' '1739' '1737' '1735' '1734' '1732' '1730'
#  '1729' '1727' '1725' '1724' '1722' '1720' '1719' '1717' '1715' '1714'
#  '1712' '1711' '1709' '1707' '1706' '1704' '1703' '1701' '1660' '1658'
#  '1657' '1656' '1654' '1653' '1651' '1650' '1649' '1647']
# [' ' 'BR' 'BR HZ' 'HZ' 'RA' 'RA BR' 'TSRA RA BR' 'RA VCTS' 'TSRA RA'
#  'RA HZ' 'TSRA RA BR HZ' 'TSRA BR HZ' 'RA BR HZ VCTS' 'TSRA RA HZ'
#  'TSRA BR HZ VCTS' 'TSRA' 'TSRA BR HZ FU' 'TSRA RA HZ FU' 'BR HZ FU'
#  'TSRA RA VCTS' 'HZ VCTS' 'TSRA HZ' 'VCTS' 'RA BR VCTS' 'TSRA RA BR VCTS'
#  'TS TSRA RA BR HZ VCTS' 'DZ BR' 'TS TSRA RA BR HZ' 'TS TSRA BR HZ'
#  'RA BR HZ' 'TSRA RA DZ BR HZ' 'TS TSRA RA BR' 'TS RA BR' 'TS TSRA RA'
#  'TS TSRA RA BR VCTS' 'TS TSRA BR' 'TS RA' 'RA BCFG BR' 'TSRA BR'
#  'RA DZ FG+ BCFG BR' 'RA FG+ MIFG BR' 'RA DZ' 'RA DZ BR' 'TS TSRA RA HZ'
#  'TSRA RA FG+ FG BR' 'TSRA DZ FG+ FG BR HZ' 'TS BR' 'RA BR SQ' 'TS TSRA'
#  'TSRA RA BR HZ VCTS' 'BR VCTS' 'TS' 'FG+ BR HZ' 'RA SN' 'TSRA RA DZ BR'
#  'DZ BR HZ' 'RA BR FU' 'TS BR HZ' 'DZ' 'FG+ BR' 'FG+ FG BR' 'FG+ MIFG BR'
#  'TSRA RA FG BR' 'TSRA FG+ BR' 'RA DZ BR HZ' 'RA DZ SN' 'FG+ FG BR HZ'
#  'TS TSRA RA FG BR' 'BR HZ VCFG' 'TS RA FG+ FG BR' 'TSRA RA FG+ BR'
#  'RA DZ FG+ FG BR' 'TS TSRA RA VCTS' 'FU' 'TS TSRA VCFG' 'TS TSRA HZ'
#  'TS TSRA GR RA BR' 'RA FG BR' 'HZ FU' 'RA BR HZ FU' 'MIFG BCFG BR'
#  'FG+ BCFG BR' 'TSRA RA FG+ FG BR HZ' 'FG+' 'TSRA BR SQ' 'TSRA DZ BR HZ'
#  'RA BR HZ VCFG' 'RA FG+ BR' 'FG BR HZ' 'TS HZ' 'TS TSRA RA FG BR HZ'
#  'RA DZ FG+ BR' 'RA DZ FG+ BR HZ' 'TSRA FG+ BR HZ' 'RA BR VCFG'
#  'TS RA BR HZ' 'BCFG BR' 'RA SN BR']
# ['0' 'M']
# ['M']
# ['0.0' 'M' '  T' '0.1']
# ['0.00' '  T' '0.13' '0.02' '0.38' '0.60' '0.14' '0.07' '0.11' '0.09'
#  '1.01' '0.28' '0.04' '0.08' '0.01' '0.53' '0.19' '0.21' '0.32' '0.39'
#  '0.31' '0.42' '0.27' '0.16' '0.58' '0.93' '0.05' '0.34' '0.15' '0.35' 'M'
#  '0.40' '0.66' '0.30' '0.24' '0.43' '1.55' '0.92' '0.89' '0.17' '0.03'
#  '1.43' '0.97' '0.26' '1.31' '0.06' '0.46' '0.29' '0.23' '0.41' '0.45'
#  '0.83' '1.33' '0.91' '0.48' '0.37' '0.88' '2.35' '1.96' '0.20' '0.25'
#  '0.18' '0.67' '0.36' '0.33' '1.28' '0.74' '0.76' '0.71' '0.95' '1.46'
#  '0.12' '0.52' '0.64' '0.22' '1.24' '0.72' '0.73' '0.65' '1.61' '1.22'
#  '0.50' '1.05' '2.43' '0.59' '2.90' '2.68' '1.23' '0.62' '6.64' '3.07'
#  '1.44' '1.75' '0.82' '0.80' '0.86' '0.63' '0.55' '1.03' '0.70' '1.73'
#  '1.38' '0.44' '1.14' '1.07' '3.97' '0.87' '0.78' '1.12' '0.68' '0.10'
#  '0.61' '0.54' '1.19' '0.75' '0.84' '1.29' '0.81' '1.15' '1.49' '1.57'
#  '1.02' '1.30' '0.51' '0.85' '0.79' '0.77' '2.79' '3.15' '3.64' '4.73'
#  '1.60' '0.57' '2.24' '1.90' '1.06' '1.88' '0.69' '2.17' '6.86' '0.49'
#  '1.11' '1.21' '0.90' '1.34' '0.47' '0.56' '3.66' '1.09' '1.25' '1.35'
#  '2.20' '1.48' '0.96' '1.16' '1.04' '2.03' '2.09' '1.26' '2.60' '2.06'
#  '3.31' '2.76' '1.82' '0.98' '1.58' '3.17' '1.18']
# ['29.10' '29.18' '29.38' '29.44' '29.39' '29.46' '29.31' '29.36' '29.40'
#  '29.57' '29.62' '29.29' '29.21' '29.28' '29.20' '29.26' '29.33' '29.49'
#  '29.54' '29.55' '29.23' '29.13' '29.19' '29.53' '29.60' '29.34' '29.41'
#  '29.47' '29.51' '29.42' '29.43' '29.25' '29.03' '28.82' '28.87' '28.88'
#  '29.16' '29.07' '28.84' '28.91' '29.24' 'M' '29.30' '29.12' '29.45'
#  '29.56' '29.32' '29.05' '29.11' '29.06' '29.22' '29.08' '29.14' '29.37'
#  '29.35' '29.15' '29.17' '29.48' '29.52' '29.27' '29.50' '28.59' '28.67'
#  '28.75' '29.02' '29.79' '29.86' '29.63' '29.70' '28.95' '29.01' '28.79'
#  '28.85' '28.97' '28.89' '28.94' '28.93' '28.98' '28.96' '29.00' '29.66'
#  '29.09' '28.90' '29.04' '29.59' '29.65' '29.58' '29.61' '29.64' '29.71'
#  '29.67' '28.80' '28.73' '29.68' '28.74' '28.55' '28.63' '28.92' '28.99'
#  '28.81' '28.71' '28.69' '28.77' '28.83']
# ['29.82' '30.09' '30.08' '30.12' '30.05' '30.04' '30.10' '30.29' '30.28'
#  '30.03' '30.02' '29.94' '29.93' '29.92' '29.91' '30.20' '30.19' '30.24'
#  '29.97' '29.98' '29.84' '29.83' '30.27' '30.25' '30.26' '30.11' '30.06'
#  '30.23' '30.15' '30.14' '30.00' '29.99' '29.90' '29.77' '29.76' '29.56'
#  '29.54' '29.52' '29.51' '29.79' '29.78' '29.81' '29.55' '29.85' '30.07'
#  '30.16' 'M' '29.96' '29.95' '30.13' '30.21' '30.22' '29.88' '30.01'
#  '29.80' '29.89' '29.74' '29.87' '29.86' '30.18' '30.17' '29.34' '29.44'
#  '29.45' '29.71' '29.72' '30.52' '30.53' '30.40' '30.41' '29.67' '29.53'
#  '29.69' '29.61' '29.64' '29.63' '29.66' '29.70' '30.34' '30.33' '29.62'
#  '29.60' '29.75' '29.68' '29.73' '30.31' '30.30' '30.32' '30.37' '30.39'
#  '29.59' '29.65' '30.35' '30.36' '29.48' '30.38' '29.50' '29.25' '29.23'
#  '29.46' '29.43' '29.47']
# ['9.2' '9.6' '13.4' '11.9' '13.2' '10.8' '10.4' '12.0' '11.5' '15.0'
#  '14.5' '10.5' '9.9' '5.8' '5.4' '6.2' '5.9' '4.1' '3.9' '12.9' '12.8'
#  '13.0' '8.1' '7.6' '17.3' '14.6' '12.3' '12.2' '11.8' '11.3' '7.5' '5.5'
#  '11.4' '10.7' '9.7' '8.2' '7.8' '10.2' '10.6' '11.2' '15.2' '8.8' '7.2'
#  '9.5' '5.3' '5.2' '6.5' '7.4' '10.1' '6.4' '6.7' '23.1' '20.7' '13.8'
#  '12.4' '5.0' '4.7' '5.6' '6.9' '8.4' '10.0' '8.6' 'M' '6.8' '4.9' '6.1'
#  '6.3' '15.1' '12.6' '7.7' '8.7' '9.0' '8.0' '6.0' '7.1' '8.5' '12.5'
#  '13.3' '8.3' '7.3' '13.1' '12.7' '10.9' '11.1' '13.9' '6.6' '14.4' '9.1'
#  '3.3' '3.5' '4.0' '7.0' '9.4' '7.9' '5.7' '4.3' '4.6' '3.7' '11.7' '4.4'
#  '12.1' '13.5' '13.7' '11.0' '9.8' '8.9' '10.3' '15.5' '18.9' '17.2'
#  '16.7' '18.0' '18.2' '16.8' '14.1' '14.7' '4.2' '9.3' '14.3' '17.7'
#  '17.8' '15.9' '19.3' '17.4' '3.8' '4.8' '14.0' '21.5' '19.5' '16.3' '5.1'
#  '3.6' '3.2' '4.5' '2.9' '3.1' '2.7' '18.4' '16.4' '14.8' '11.6' '13.6'
#  '2.4' '2.6' '3.4' '3.0' '2.1' '20.2' '14.9' '16.2' '15.4' '17.9' '14.2'
#  '15.3' '15.7' '16.1' '18.8' '17.1' '16.6' '26.3' '21.4' '23.2' '22.1'
#  '15.6' '16.9' '2.0' '2.3' '1.7' '19.9' '17.6' '18.5' '18.1' '16.0' '15.8'
#  '2.8' '1.9' '22.9' '22.6']

# %% [markdown]
# No null values (but there are empty strings, -, T, or M for empty values)

# %%
def get_null(weather): 
    null_df = pd.DataFrame(columns=['col', 'M', '-', 'T', 'Blank'])
    i = 0
    for col in weather.columns:
        if weather[col].dtype == 'object':
            null_df.at[i, 'col'] = col
            null_df.at[i, 'M'] = weather[col].apply(lambda x: 1 if x == 'M' else 0).sum()
            null_df.at[i, '-'] = weather[col].apply(lambda x: 1 if x == '-' else 0).sum()
            null_df.at[i, 'T'] = weather[col].apply(lambda x: 1 if x == '  T' else 0).sum()
            null_df.at[i, 'Blank'] = weather[col].apply(lambda x: 1 if x == ' ' else 0).sum()
        i += 1
    return null_df

# %%
get_null(weather)
# Out:
#             col     M     -    T Blank
# 1          Date     0     0    0     0
# 4          Tavg    11     0    0     0
# 5        Depart  1472     0    0     0
# 7       WetBulb     4     0    0     0
# 8          Heat    11     0    0     0
# 9          Cool    11     0    0     0
# 10      Sunrise     0  1472    0     0
# 11       Sunset     0  1472    0     0
# 12      CodeSum     0     0    0  1609
# 13        Depth  1472     0    0     0
# 14       Water1  2944     0    0     0
# 15     SnowFall  1472     0   12     0
# 16  PrecipTotal     2     0  318     0
# 17  StnPressure     4     0    0     0
# 18     SeaLevel     9     0    0     0
# 21     AvgSpeed     3     0    0     0

# %% [markdown]
# 1. M = Missing
# 2. '-' = Missing
# 3. T = Low value
# 4. Blank = Missing

# %%
station_one = weather[weather['Station'] == 1]
station_one.head()
# Out:
#    Station        Date  Tmax  Tmin Tavg Depart  DewPoint WetBulb Heat Cool  \
# 0        1  2007-05-01    83    50   67     14        51      56    0    2
# 2        1  2007-05-02    59    42   51     -3        42      47   14    0
# 4        1  2007-05-03    66    46   56      2        40      48    9    0
# 6        1  2007-05-04    66    49   58      4        41      50    7    0
# 8        1  2007-05-05    66    53   60      5        38      49    5    0
#
#    ... CodeSum Depth Water1 SnowFall PrecipTotal StnPressure SeaLevel  \
# 0  ...             0      M      0.0        0.00       29.10    29.82
# 2  ...      BR     0      M      0.0        0.00       29.38    30.09
# 4  ...             0      M      0.0        0.00       29.39    30.12
# 6  ...      RA     0      M      0.0           T       29.31    30.05
# 8  ...             0      M      0.0           T       29.40    30.10
#
#   ResultSpeed ResultDir  AvgSpeed
# 0         1.7        27       9.2
# 2        13.0         4      13.4
# 4        11.7         7      11.9
# 6        10.4         8      10.8
# 8        11.7         7      12.0
#
# [5 rows x 22 columns]

# %%
get_null(station_one)
# Out:
#             col     M  -    T Blank
# 1          Date     0  0    0     0
# 4          Tavg     0  0    0     0
# 5        Depart     0  0    0     0
# 7       WetBulb     3  0    0     0
# 8          Heat     0  0    0     0
# 9          Cool     0  0    0     0
# 10      Sunrise     0  0    0     0
# 11       Sunset     0  0    0     0
# 12      CodeSum     0  0    0   805
# 13        Depth     0  0    0     0
# 14       Water1  1472  0    0     0
# 15     SnowFall     0  0   12     0
# 16  PrecipTotal     0  0  163     0
# 17  StnPressure     2  0    0     0
# 18     SeaLevel     5  0    0     0
# 21     AvgSpeed     0  0    0     0

# %%
station_two = weather[weather['Station'] == 2]
station_two.head()
# Out:
#    Station        Date  Tmax  Tmin Tavg Depart  DewPoint WetBulb Heat Cool  \
# 1        2  2007-05-01    84    52   68      M        51      57    0    3
# 3        2  2007-05-02    60    43   52      M        42      47   13    0
# 5        2  2007-05-03    67    48   58      M        40      50    7    0
# 7        2  2007-05-04    78    51    M      M        42      50    M    M
# 9        2  2007-05-05    66    54   60      M        39      50    5    0
#
#    ... CodeSum Depth Water1 SnowFall PrecipTotal StnPressure SeaLevel  \
# 1  ...             M      M        M        0.00       29.18    29.82
# 3  ...   BR HZ     M      M        M        0.00       29.44    30.08
# 5  ...      HZ     M      M        M        0.00       29.46    30.12
# 7  ...             M      M        M        0.00       29.36    30.04
# 9  ...             M      M        M           T       29.46    30.09
#
#   ResultSpeed ResultDir  AvgSpeed
# 1         2.7        25       9.6
# 3        13.3         2      13.4
# 5        12.9         6      13.2
# 7        10.1         7      10.4
# 9        11.2         7      11.5
#
# [5 rows x 22 columns]

# %%
get_null(station_two)
# Out:
#             col     M     -    T Blank
# 1          Date     0     0    0     0
# 4          Tavg    11     0    0     0
# 5        Depart  1472     0    0     0
# 7       WetBulb     1     0    0     0
# 8          Heat    11     0    0     0
# 9          Cool    11     0    0     0
# 10      Sunrise     0  1472    0     0
# 11       Sunset     0  1472    0     0
# 12      CodeSum     0     0    0   804
# 13        Depth  1472     0    0     0
# 14       Water1  1472     0    0     0
# 15     SnowFall  1472     0    0     0
# 16  PrecipTotal     2     0  155     0
# 17  StnPressure     2     0    0     0
# 18     SeaLevel     4     0    0     0
# 21     AvgSpeed     3     0    0     0

# %% [markdown]
# #### Sunrise/Sunset (Since the report is on the same day. Sunrise/Sunset time should be the same in both channel)
# #### Same goes for Depart and SnowFall

# %%
weather['SnowFall'] = weather['SnowFall'].apply(lambda x: float(x) if x.isdigit() else 0.0)

# %%
i = 0
while i < weather.shape[0]:
    weather.loc[i+1, 'Sunrise'] = weather.loc[i, 'Sunrise']
    weather.loc[i+1, 'Sunset'] = weather.loc[i, 'Sunset']
    weather.loc[i+1, 'SnowFall'] = weather.loc[i, 'SnowFall']
    weather.loc[i+1, 'Depart'] = weather.loc[i, 'Depart']
    i+=2

# %%
weather['Depart'] = weather['Depart'].apply(lambda x: int(x))

# %%
weather
# Out:
#       Station        Date  Tmax  Tmin Tavg  Depart  DewPoint WetBulb Heat  \
# 0           1  2007-05-01    83    50   67      14        51      56    0
# 1           2  2007-05-01    84    52   68      14        51      57    0
# 2           1  2007-05-02    59    42   51      -3        42      47   14
# 3           2  2007-05-02    60    43   52      -3        42      47   13
# 4           1  2007-05-03    66    46   56       2        40      48    9
# ...       ...         ...   ...   ...  ...     ...       ...     ...  ...
# 2939        2  2014-10-29    49    40   45      -4        34      42   20
# 2940        1  2014-10-30    51    32   42      -4        34      40   23
# 2941        2  2014-10-30    53    37   45      -4        35      42   20
# 2942        1  2014-10-31    47    33   40      -6        25      33   25
# 2943        2  2014-10-31    49    34   42      -6        29      36   23
#
#      Cool  ...   CodeSum Depth Water1 SnowFall PrecipTotal  StnPressure  \
# 0       2  ...               0      M      0.0        0.00        29.10
# 1       3  ...               M      M      0.0        0.00        29.18
# 2       0  ...        BR     0      M      0.0        0.00        29.38
# 3       0  ...     BR HZ     M      M      0.0        0.00        29.44
# 4       0  ...               0      M      0.0        0.00        29.39
# ...   ...  ...       ...   ...    ...      ...         ...          ...
# 2939    0  ...               M      M      0.0        0.00        29.42
# 2940    0  ...               0      M      0.0        0.00        29.34
# 2941    0  ...        RA     M      M      0.0           T        29.41
# 2942    0  ...     RA SN     0      M      0.0        0.03        29.49
# 2943    0  ...  RA SN BR     M      M      0.0        0.04        29.54
#
#      SeaLevel ResultSpeed ResultDir  AvgSpeed
# 0       29.82         1.7        27       9.2
# 1       29.82         2.7        25       9.6
# 2       30.09        13.0         4      13.4
# 3       30.08        13.3         2      13.4
# 4       30.12        11.7         7      11.9
# ...       ...         ...       ...       ...
# 2939    30.07         8.5        29       9.0
# 2940    30.09         5.1        24       5.5
# 2941    30.10         5.9        23       6.5
# 2942    30.20        22.6        34      22.9
# 2943    30.20        21.7        34      22.6
#
# [2944 rows x 22 columns]

# %%
weather.columns
# Out:
# Index(['Station', 'Date', 'Tmax', 'Tmin', 'Tavg', 'Depart', 'DewPoint',
#        'WetBulb', 'Heat', 'Cool', 'Sunrise', 'Sunset', 'CodeSum', 'Depth',
#        'Water1', 'SnowFall', 'PrecipTotal', 'StnPressure', 'SeaLevel',
#        'ResultSpeed', 'ResultDir', 'AvgSpeed'],
#       dtype='object')

# %% [markdown]
# #### Water1

# %%
weather = weather.drop(labels='Water1', axis=1)

# %% [markdown]
# #### Date

# %%
weather.Date = pd.to_datetime(weather.Date)

# %% [markdown]
# #### Tavg

# %%
weather.head()
# Out:
#    Station       Date  Tmax  Tmin Tavg  Depart  DewPoint WetBulb Heat Cool  \
# 0        1 2007-05-01    83    50   67      14        51      56    0    2
# 1        2 2007-05-01    84    52   68      14        51      57    0    3
# 2        1 2007-05-02    59    42   51      -3        42      47   14    0
# 3        2 2007-05-02    60    43   52      -3        42      47   13    0
# 4        1 2007-05-03    66    46   56       2        40      48    9    0
#
#    ... Sunset CodeSum Depth SnowFall  PrecipTotal StnPressure SeaLevel  \
# 0  ...   1849             0      0.0         0.00       29.10    29.82
# 1  ...   1849             M      0.0         0.00       29.18    29.82
# 2  ...   1850      BR     0      0.0         0.00       29.38    30.09
# 3  ...   1850   BR HZ     M      0.0         0.00       29.44    30.08
# 4  ...   1851             0      0.0         0.00       29.39    30.12
#
#   ResultSpeed  ResultDir  AvgSpeed
# 0         1.7         27       9.2
# 1         2.7         25       9.6
# 2        13.0          4      13.4
# 3        13.3          2      13.4
# 4        11.7          7      11.9
#
# [5 rows x 21 columns]

# %% [markdown]
# Based on Tavg from .head() it is (Tmax+Tmin)/2 then rounded up to a whole number

# %%
weather['Tavg'] = ((weather['Tmax'] + weather['Tmin'])/2)
weather['Tavg'] = weather['Tavg'].apply(lambda x: math.ceil(x))

# %% [markdown]
# #### Stn Pressure

# %%
weather['StnPressure'] = weather['StnPressure'].apply(lambda x: float(x) if x.isdigit() else weather.StnPressure.mode())
weather['StnPressure'] = weather['StnPressure'].apply(lambda x: float(x))

# %% [markdown]
# #### Avg Speed

# %%
weather['AvgSpeed'] = weather['AvgSpeed'].apply(lambda x: float(x) if x != 'M' else np.nan)

# %%
weather.AvgSpeed.sort_values()
# Out:
# 1785     1.7
# 2870     1.9
# 1737     2.0
# 2049     2.1
# 1008     2.1
#         ...
# 1462    23.2
# 1460    26.3
# 87       NaN
# 1745     NaN
# 2067     NaN
# Name: AvgSpeed, Length: 2944, dtype: float64

# %%
weather.AvgSpeed.mode()
# Out:
# 0    6.9
# dtype: float64

# %%
weather.AvgSpeed.median()
# Out:
# 8.1

# %%
round(weather.AvgSpeed.mean(), 1)
# Out:
# 8.6

# %%
weather['AvgSpeed'].fillna(round(weather.AvgSpeed.mean(), 1), inplace=True)

# %% [markdown]
# #### Sea Level

# %%
weather['SeaLevel'] = weather['SeaLevel'].apply(lambda x: float(x) if x != 'M' else np.nan)

# %%
weather.SeaLevel.sort_values().tail(10)
# Out:
# 361     30.53
# 87        NaN
# 832       NaN
# 994       NaN
# 1732      NaN
# 1745      NaN
# 1756      NaN
# 2067      NaN
# 2090      NaN
# 2743      NaN
# Name: SeaLevel, dtype: float64

# %%
weather.SeaLevel.sort_values()
# Out:
# 1461    29.23
# 1460    29.25
# 341     29.34
# 340     29.34
# 2180    29.43
#         ...
# 1745      NaN
# 1756      NaN
# 2067      NaN
# 2090      NaN
# 2743      NaN
# Name: SeaLevel, Length: 2944, dtype: float64

# %%
weather.SeaLevel.mean()
# Out:
# 29.968129471890993

# %%
weather.SeaLevel.median()
# Out:
# 29.97

# %%
weather.SeaLevel.mode()
# Out:
# 0    30.0
# dtype: float64

# %%
weather['SeaLevel'].fillna(round(weather.SeaLevel.median()), inplace=True)

# %% [markdown]
# #### WetBulb

# %%
weather[weather['WetBulb']=='M']
# Out:
#       Station       Date  Tmax  Tmin  Tavg  Depart  DewPoint WetBulb Heat  \
# 848         1 2009-06-26    86    69    78       7        60       M    0
# 2410        1 2013-08-10    81    64    73       0        57       M    0
# 2412        1 2013-08-11    81    60    71      -2        61       M    0
# 2415        2 2013-08-12    85    69    77       2        63       M    0
#
#      Cool  ... Sunset CodeSum Depth SnowFall  PrecipTotal StnPressure  \
# 848    13  ...   1931             0      0.0         0.00       29.34
# 2410    8  ...   1900             0      0.0         0.00       29.34
# 2412    6  ...   1859      RA     0      0.0         0.01       29.34
# 2415   12  ...   1858      RA     M      0.0         0.66       29.34
#
#       SeaLevel  ResultSpeed  ResultDir  AvgSpeed
# 848      29.85          6.4          4       8.2
# 2410     30.08          5.3          5       6.5
# 2412     30.07          2.0         27       3.0
# 2415     29.92          4.5         26       7.7
#
# [4 rows x 21 columns]

# %%
weather['WetBulb'] = weather['WetBulb'].apply(lambda x: float(x) if x != 'M' else np.nan)

# %%
weather.WetBulb.median()
# Out:
# 61.0

# %%
weather.WetBulb.mean()
# Out:
# 59.3108843537415

# %%
weather.WetBulb.mode()
# Out:
# 0    63.0
# dtype: float64

# %%
weather['WetBulb'].fillna(round(weather.WetBulb.median()), inplace=True)

# %% [markdown]
# #### Depth
# 1. Can be dropped (only contain 0)

# %%
weather.drop('Depth', axis=1, inplace=True)

# %% [markdown]
# #### Heat/Cool (Where Heat is missing, cool misses as well)

# %%
weather[weather['Heat'] == 'M']
# Out:
#       Station       Date  Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb Heat  \
# 7           2 2007-05-04    78    51    65       4        42     50.0    M
# 505         2 2008-07-08    86    46    66       5        68     71.0    M
# 675         2 2008-10-01    62    46    54      -4        41     47.0    M
# 1637        2 2011-07-22   100    71    86       5        70     74.0    M
# 2067        2 2012-08-22    84    72    78      -1        51     61.0    M
# 2211        2 2013-05-02    71    42    57      -5        39     45.0    M
# 2501        2 2013-09-24    91    52    72      -1        48     54.0    M
# 2511        2 2013-09-29    84    53    69       1        48     54.0    M
# 2525        2 2013-10-06    76    48    62      -1        44     50.0    M
# 2579        2 2014-05-02    80    47    64      -4        43     47.0    M
# 2811        2 2014-08-26    86    49    68       8        68     71.0    M
#
#      Cool Sunrise Sunset     CodeSum  SnowFall PrecipTotal  StnPressure  \
# 7       M    0444   1852                   0.0        0.00        29.34
# 505     M    0424   1929       TS RA       0.0        0.28        29.34
# 675     M    0548   1734                   0.0        0.00        29.34
# 1637    M    0435   1921  TS TSRA BR       0.0        0.14        29.34
# 2067    M    0506   1843                   0.0        0.00        29.34
# 2211    M    0447   1850                   0.0        0.00        29.34
# 2501    M    0541   1746                   0.0        0.00        29.34
# 2511    M    0546   1737       RA BR       0.0        0.22        29.34
# 2525    M    0554   1725    RA DZ BR       0.0        0.06        29.34
# 2579    M    0447   1850          RA       0.0        0.04        29.34
# 2811    M    0511   1837                   0.0           T        29.34
#
#       SeaLevel  ResultSpeed  ResultDir  AvgSpeed
# 7        30.04         10.1          7      10.4
# 505      29.80          7.4         24       8.3
# 675      29.96         10.9         33      11.0
# 1637     29.86          3.8         10       8.2
# 2067     30.00          4.7         19       8.6
# 2211     30.17         15.8          2      16.1
# 2501     30.00          5.8          9       7.7
# 2511     30.01          6.3         36       7.8
# 2525     29.76         10.1         25      10.6
# 2579     29.79         10.7         23      11.9
# 2811     30.04          1.3         15       5.8

# %%
weather.head()
# Out:
#    Station       Date  Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb Heat Cool  \
# 0        1 2007-05-01    83    50    67      14        51     56.0    0    2
# 1        2 2007-05-01    84    52    68      14        51     57.0    0    3
# 2        1 2007-05-02    59    42    51      -3        42     47.0   14    0
# 3        2 2007-05-02    60    43    52      -3        42     47.0   13    0
# 4        1 2007-05-03    66    46    56       2        40     48.0    9    0
#
#   Sunrise Sunset CodeSum  SnowFall PrecipTotal  StnPressure  SeaLevel  \
# 0    0448   1849               0.0        0.00        29.34     29.82
# 1    0448   1849               0.0        0.00        29.34     29.82
# 2    0447   1850      BR       0.0        0.00        29.34     30.09
# 3    0447   1850   BR HZ       0.0        0.00        29.34     30.08
# 4    0446   1851               0.0        0.00        29.34     30.12
#
#    ResultSpeed  ResultDir  AvgSpeed
# 0          1.7         27       9.2
# 1          2.7         25       9.6
# 2         13.0          4      13.4
# 3         13.3          2      13.4
# 4         11.7          7      11.9

# %% [markdown]
# Data is missing on station 2. However the heat/cool should be similar on station 1 and 2. Data from station will be used to replace the missing values

# %%
col = list(weather[weather['Heat'] == 'M'].index)
for i in col:
    weather.loc[i, 'Heat'] = weather.loc[i-1, 'Heat']
    weather.loc[i, 'Cool'] = weather.loc[i-1, 'Cool']

# %%
weather['Heat'] = weather['Heat'].apply(lambda x: int(x))
weather['Cool'] = weather['Cool'].apply(lambda x: int(x))

# %% [markdown]
# #### PrecipTotal

# %%
weather[weather['PrecipTotal']=='M']
# Out:
#      Station       Date  Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb  Heat  \
# 117        2 2007-06-28    73    61    67      -5        56     61.0     0
# 119        2 2007-06-29    71    56    64      -8        56     60.0     1
#
#      Cool Sunrise Sunset CodeSum  SnowFall PrecipTotal  StnPressure  SeaLevel  \
# 117     2    0419   1931               0.0           M        29.34     30.07
# 119     0    0419   1931               0.0           M        29.34     30.11
#
#      ResultSpeed  ResultDir  AvgSpeed
# 117         12.2          2      13.3
# 119          7.4          2       8.2

# %%
weather.iloc[116:120]
# Out:
#      Station       Date  Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb  Heat  \
# 116        1 2007-06-28    74    58    66      -5        55     60.0     0
# 117        2 2007-06-28    73    61    67      -5        56     61.0     0
# 118        1 2007-06-29    70    56    63      -8        55     59.0     2
# 119        2 2007-06-29    71    56    64      -8        56     60.0     1
#
#      Cool Sunrise Sunset CodeSum  SnowFall PrecipTotal  StnPressure  SeaLevel  \
# 116     1    0419   1931               0.0        0.00        29.34     30.09
# 117     2    0419   1931               0.0           M        29.34     30.07
# 118     0    0419   1931               0.0        0.00        29.34     30.13
# 119     0    0419   1931               0.0           M        29.34     30.11
#
#      ResultSpeed  ResultDir  AvgSpeed
# 116         11.9          3      12.5
# 117         12.2          2      13.3
# 118          7.6          2       8.3
# 119          7.4          2       8.2

# %%
weather['PrecipTotal'] = weather['PrecipTotal'].apply(lambda x: float(x) if x.isdecimal() else 0.0)

# %% [markdown]
# ## Last check on dtypes and Objects' null values

# %%
weather.dtypes
# Out:
# Station                 int64
# Date           datetime64[ns]
# Tmax                    int64
# Tmin                    int64
# Tavg                    int64
# Depart                  int64
# DewPoint                int64
# WetBulb               float64
# Heat                    int64
# Cool                    int64
# Sunrise                object
# Sunset                 object
# CodeSum                object
# SnowFall              float64
# PrecipTotal           float64
# StnPressure           float64
# SeaLevel              float64
# ResultSpeed           float64
# ResultDir               int64
# AvgSpeed              float64
# dtype: object

# %%
get_null(weather)
# Out:
#         col  M  -  T Blank
# 10  Sunrise  0  0  0     0
# 11   Sunset  0  0  0     0
# 12  CodeSum  0  0  0  1609

# %% [markdown]
# #### DayLight

# %%
weather['Sunrise'] = weather['Sunrise'].apply(lambda x: int(x))
weather['Sunset'] = weather['Sunset'].apply(lambda x: int(x))

# %%
weather['Daylight'] = weather['Sunset'] - weather['Sunrise']

# %%
def to_min(x):
    hour = round(x / 100)
    remainder = x%100
    return (hour * 60) + remainder

# %%
weather['Daylight'] = weather['Daylight'].apply(lambda x: to_min(x))

# %% [markdown]
# ### Export

# %%
weather.to_csv('./clean_data/weather_clean.csv', index = False)

# %% [markdown]
# ---

# %% [markdown]
# ## Train/Test Datasets

# %%
train = pd.read_csv('dataset/train.csv')
train.head()
# Out:
#          Date                                            Address  \
# 0  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2  2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 3  2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 4  2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
#
#                   Species  Block           Street  Trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 1          CULEX RESTUANS     41   N OAK PARK AVE  T002
# 2          CULEX RESTUANS     62    N MANDELL AVE  T007
# 3  CULEX PIPIENS/RESTUANS     79     W FOSTER AVE  T015
# 4          CULEX RESTUANS     79     W FOSTER AVE  T015
#
#               AddressNumberAndStreet   Latitude  Longitude  AddressAccuracy  \
# 0  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 1  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 2   6200  N MANDELL AVE, Chicago, IL  41.994991 -87.769279                9
# 3    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812                8
# 4    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812                8
#
#    NumMosquitos  WnvPresent
# 0             1           0
# 1             1           0
# 2             1           0
# 3             1           0
# 4             4           0

# %%
test = pd.read_csv('dataset/test.csv')
test.head()
# Out:
#    Id        Date                                            Address  \
# 0   1  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1   2  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2   3  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 3   4  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 4   5  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
#
#                   Species  Block           Street  Trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 1          CULEX RESTUANS     41   N OAK PARK AVE  T002
# 2           CULEX PIPIENS     41   N OAK PARK AVE  T002
# 3        CULEX SALINARIUS     41   N OAK PARK AVE  T002
# 4         CULEX TERRITANS     41   N OAK PARK AVE  T002
#
#               AddressNumberAndStreet  Latitude  Longitude  AddressAccuracy
# 0  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991                9
# 1  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991                9
# 2  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991                9
# 3  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991                9
# 4  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991                9

# %%
train.WnvPresent.value_counts(normalize=True)
# Out:
# 0    0.947554
# 1    0.052446
# Name: WnvPresent, dtype: float64

# %%
train.isnull().sum()
# Out:
# Date                      0
# Address                   0
# Species                   0
# Block                     0
# Street                    0
# Trap                      0
# AddressNumberAndStreet    0
# Latitude                  0
# Longitude                 0
# AddressAccuracy           0
# NumMosquitos              0
# WnvPresent                0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Id                        0
# Date                      0
# Address                   0
# Species                   0
# Block                     0
# Street                    0
# Trap                      0
# AddressNumberAndStreet    0
# Latitude                  0
# Longitude                 0
# AddressAccuracy           0
# dtype: int64

# %%
train.dtypes
# Out:
# Date                       object
# Address                    object
# Species                    object
# Block                       int64
# Street                     object
# Trap                       object
# AddressNumberAndStreet     object
# Latitude                  float64
# Longitude                 float64
# AddressAccuracy             int64
# NumMosquitos                int64
# WnvPresent                  int64
# dtype: object

# %%
test.dtypes
# Out:
# Id                          int64
# Date                       object
# Address                    object
# Species                    object
# Block                       int64
# Street                     object
# Trap                       object
# AddressNumberAndStreet     object
# Latitude                  float64
# Longitude                 float64
# AddressAccuracy             int64
# dtype: object

# %%
test.drop('Id', axis=1, inplace=True)

# %%
train['Date'] = pd.to_datetime(train['Date'])

# %%
test['Date'] = pd.to_datetime(test['Date'])

# %%
train.shape
# Out:
# (10506, 12)

# %%
test.duplicated().sum()
# Out:
# 1533

# %% [markdown]
# #### Station Col

# %%
train['Longitude'] = train['Longitude'].apply(lambda x: str(x))
train['Latitude'] = train['Latitude'].apply(lambda x: str(x))

test['Longitude'] = test['Longitude'].apply(lambda x: str(x))
test['Latitude'] = test['Latitude'].apply(lambda x: str(x))

train['Station'] = train['Latitude'] + ' ' + train['Longitude']
test['Station'] = test['Latitude'] + ' ' + test['Longitude']

# %%
train.Station[:3]
# Out:
# 0     41.95469 -87.800991
# 1     41.95469 -87.800991
# 2    41.994991 -87.769279
# Name: Station, dtype: object

# %%
def get_station(x):
    list_temp = x.split()
    lat = float(list_temp[0])
    long = float(list_temp[1])
    
    if ((lat-41.995)**2 + (long+87.933)**2) < ((lat-41.786)**2 + (long+87.752)**2):
        return 1
    else:
        return 2

# %%
train['Station'] = train['Station'].apply(lambda x: get_station(x))

# %%
test['Station'] = test['Station'].apply(lambda x: get_station(x))

# %%
train.Station.value_counts()
# Out:
# 2    8245
# 1    2261
# Name: Station, dtype: int64

# %% [markdown]
# ### Export

# %%
train.to_csv('./clean_data/train_clean.csv', index = False)
test.to_csv('./clean_data/test_clean.csv', index = False)

# %% [markdown]
# ---

# %% [markdown]
# 1. Rid of dupes by adding total Mus count to one row.

# %%
train_clean = pd.read_csv('./clean_data/train_clean.csv')
test_clean = pd.read_csv('./clean_data/test_clean.csv')

# %%
train_clean.head()
# Out:
#          Date                                            Address  \
# 0  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2  2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 3  2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 4  2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
#
#                   Species  Block           Street  Trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 1          CULEX RESTUANS     41   N OAK PARK AVE  T002
# 2          CULEX RESTUANS     62    N MANDELL AVE  T007
# 3  CULEX PIPIENS/RESTUANS     79     W FOSTER AVE  T015
# 4          CULEX RESTUANS     79     W FOSTER AVE  T015
#
#               AddressNumberAndStreet   Latitude  Longitude  AddressAccuracy  \
# 0  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 1  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 2   6200  N MANDELL AVE, Chicago, IL  41.994991 -87.769279                9
# 3    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812                8
# 4    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812                8
#
#    NumMosquitos  WnvPresent  Station
# 0             1           0        1
# 1             1           0        1
# 2             1           0        1
# 3             1           0        1
# 4             4           0        1

# %%
test_clean.shape
# Out:
# (116293, 11)

# %%
# merge nummosquitos and wnvpresent for duplicated rows

# create train_2 (new copy)
# to compare train and train_2 and verify code
train_2 = train_clean.copy()

# duplicated rows have the same values for the columns below
cols = ['Date','Species','Trap','Address','Block', 'Street','Trap', 'AddressNumberAndStreet','Latitude','Longitude', 'Station' ]

for row_idx,row in train_2.iterrows():
    
    # skip 1st row
    if row_idx > 0:
        
        # reset counter for each row
        duplicate_count = 0        
        
        for col in cols:
            
            # compare cells in current and previous rows
            # increment counter if both cells have the same value 
            if train_2.at[row_idx,col] == train_2.at[row_idx-1,col]:
                duplicate_count += 1               
                
        # counter equal to number of selected column
        # current row['nummosquitos','wnvpresent'] = sum of current and previous rows
        if duplicate_count == len(cols):
            train_2.at[row_idx,'NumMosquitos'] = train_2.at[row_idx,'NumMosquitos'] + train_2.at[row_idx-1,'NumMosquitos']
            train_2.at[row_idx,'WnvPresent'] = train_2.at[row_idx,'WnvPresent'] + train_2.at[row_idx-1,'WnvPresent']

# remove duplicated rows (keep only last row)
train_2.drop_duplicates(subset=cols, keep='last',inplace=True)

# %%
train_2.shape
# Out:
# (8475, 13)

# %%
train_2.head()
# Out:
#          Date                                            Address  \
# 0  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2  2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 3  2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 4  2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
#
#                   Species  Block           Street  Trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 1          CULEX RESTUANS     41   N OAK PARK AVE  T002
# 2          CULEX RESTUANS     62    N MANDELL AVE  T007
# 3  CULEX PIPIENS/RESTUANS     79     W FOSTER AVE  T015
# 4          CULEX RESTUANS     79     W FOSTER AVE  T015
#
#               AddressNumberAndStreet   Latitude  Longitude  AddressAccuracy  \
# 0  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 1  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 2   6200  N MANDELL AVE, Chicago, IL  41.994991 -87.769279                9
# 3    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812                8
# 4    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812                8
#
#    NumMosquitos  WnvPresent  Station
# 0             1           0        1
# 1             1           0        1
# 2             1           0        1
# 3             1           0        1
# 4             4           0        1

# %%
train_2['WnvPresent'].value_counts()
# Out:
# 0     8018
# 1      409
# 2       31
# 3        9
# 4        2
# 7        1
# 6        1
# 5        1
# 10       1
# 9        1
# 8        1
# Name: WnvPresent, dtype: int64

# %%
# check total nummosquitos and wnvpresent

print(train['NumMosquitos'].sum())
print(train['WnvPresent'].sum())
print('')

print(train_2['NumMosquitos'].sum())
print(train_2['WnvPresent'].sum())
print('')

print(train_2['WnvPresent'].unique())
# Out:
# 135039
# 551
#
# 135039
# 551
#
# [ 0  1  2  3 10  7  6  4  9  8  5]

# %%
# Since WnvPresent: whether West Nile Virus was present in these mosquitos. 1 means WNV is present, and 0 means not present
# Then, convert wnvpresent: total count to 0 or 1

for row_idx,row in train_2.iterrows():
    
    if row['WnvPresent'] > 1:
        #print(row_idx,row['wnvpresent'])
        train_2.at[row_idx,'WnvPresent'] = 1
        
print(train_2['WnvPresent'].sum())
print(train_2['WnvPresent'].unique())
# Out:
# 457
# [0 1]

# %%
# show dataframe info

print(train_2.shape)
print(test_clean.shape)
print('')

print(train_2.columns)
print('')

print(test_clean.columns)
# Out:
# (8475, 13)
# (116293, 11)
#
# Index(['Date', 'Address', 'Species', 'Block', 'Street', 'Trap',
#        'AddressNumberAndStreet', 'Latitude', 'Longitude', 'AddressAccuracy',
#        'NumMosquitos', 'WnvPresent', 'Station'],
#       dtype='object')
#
# Index(['Date', 'Address', 'Species', 'Block', 'Street', 'Trap',
#        'AddressNumberAndStreet', 'Latitude', 'Longitude', 'AddressAccuracy',
#        'Station'],
#       dtype='object')

# %%
train_2.to_csv('./clean_data/train_clean_final.csv')

# %%
train_clean_final = pd.read_csv('./clean_data/train_clean_final.csv')

# %%
train_clean_final.shape
# Out:
# (8475, 14)

# %%
train_clean.shape
# Out:
# (10506, 13)
